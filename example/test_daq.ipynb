# %%
import os
import yaml
from tjmonopix2.system.bdaq53 import BDAQ53
from tjmonopix2.system.tjmonopix2 import TJMonoPix2

# %%
# Initialization
with open(os.path.join('..', 'tjmonopix2', 'system', 'bdaq53.yaml'), 'r') as f:
    cnfg = yaml.full_load(f)

daq = BDAQ53(cnfg)
daq.init()
# Out:
# 2026-07-10 09:59:52,779 [TJ-Monopix2      ] - SUCCESS Found board BDAQ53 running firmware version 0.1
# 2026-07-10 09:59:52,907 [basil.HL.si570   ] - INFO    Changed Si570 reference frequency to 160.0 MHz

# %%
daq['DAQ_CONTROL']['MPXOBX_ENABLE'] = 0
daq['DAQ_CONTROL']['MPXOBX_RESET'] = 0

daq['DAQ_CONTROL'].write()

# %%
chip = TJMonoPix2(daq, chip_id=16)
chip.init()
# Out:
# 2026-07-10 09:55:04,556 [TJ-Monopix2 - W00R00] - WARNING No explicit configuration supplied. Using 'default.cfg.yaml'!
# 2026-07-10 09:55:04,579 [TJ-Monopix2 - W00R00] - INFO    Initializing communication...
# 2026-07-10 09:55:04,581 [TJ-Monopix2 - W00R00] - SUCCESS Communication established

# %%
# chip.masks['enable'][0:512, 0:512] = False
for i in range(16):
    chip._write_register(171 + i, 0x0000)

# %%
# Testing
chip.registers["ITHR"].write(50)  # Write registers using register object
chip._write_register(151, 25)  # Write registers directly

chip.masks["enable"][:2, :] = True  # Usage of masks as 2d-array with regular python indexing
chip.masks.update()

daq.rx_channels["rx0"].set_en(True)  # Enable RX module in firmware

daq.reset_fifo()  # Clear FIFO before reading data
raw_data = daq["FIFO"].get_data()  # Get FIFO contents
hit_data, reg_data = chip.interpret_data(raw_data)  # Interpret data

print(chip.registers["ITHR"].read())  # Read registers using register object
print(chip._get_register_value(151))  # Read registers (almost) directly
# Out:
# interpret_data: sof is missing 0 0x2a
# interpret_data: sof is missing 4 0xbb
# interpret_data: sof is missing 8 0x0
# interpret_data: sof is missing 12 0xaf
# interpret_data: sof is missing 16 0xe1
# interpret_data: sof is missing 20 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x30
# interpret_data: sof is missing 4 0xf7
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 12 0x9b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb0
# interpret_data: sof is missing 4 0x8f
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 12 0xf5
# interpret_data: sof is missing 16 0x5d
# interpret_data: sof is missing 20 0x17
# interpret_data: sof is missing 24 0xb0
# interpret_data: sof is missing 28 0x57
# interpret_data: sof is missing 32 0x17
# interpret_data: sof is missing 36 0x4a
# interpret_data: sof is missing 40 0x4a
# interpret_data: sof is missing 44 0x0
# interpret_data: sof is missing 48 0x57
# interpret_data: sof is missing 52 0xb5
# interpret_data: sof is missing 56 0xb5
# interpret_data: sof is missing 60 0xb5
# interpret_data: sof is missing 64 0x40
# interpret_data: sof is missing 68 0x84
# interpret_data: sof is missing 72 0x5d
# interpret_data: sof is missing 76 0xe4
# interpret_data: sof is missing 80 0x0
# interpret_data: sof is missing 84 0xf0
# interpret_data: sof is missing 88 0x95
# interpret_data: sof is missing 92 0x5f
# interpret_data: sof is missing 96 0xb5
# interpret_data: sof is missing 100 0x30
# interpret_data: sof is missing 104 0x5f
# interpret_data: sof is missing 108 0x95
# interpret_data: sof is missing 112 0xff
# interpret_data: sof is missing 116 0xe4
# interpret_data: sof is missing 120 0x5d
# interpret_data: sof is missing 124 0xb5
# interpret_data: sof is missing 128 0xa1
# interpret_data: sof is missing 132 0x5f
# interpret_data: sof is missing 136 0xf7
# interpret_data: sof is missing 140 0xa1
# interpret_data: sof is missing 144 0x2a
# interpret_data: sof is missing 148 0x35
# interpret_data: sof is missing 152 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x2f
# interpret_data: sof is missing 4 0x9b
# interpret_data: sof is missing 8 0xa1
# interpret_data: sof is missing 12 0xe4
# interpret_data: sof is missing 16 0x0
# interpret_data: sof is missing 20 0xa1
# interpret_data: sof is missing 24 0x4a
# interpret_data: sof is missing 28 0x3f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: sof is missing 4 0x3f
# interpret_data: sof is missing 8 0x24
# interpret_data: sof is missing 12 0xef
# interpret_data: sof is missing 16 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0xb5
# interpret_data: sof is missing 8 0xa1
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xf5
# interpret_data: sof is missing 20 0x5f
# interpret_data: sof is missing 24 0x57
# interpret_data: sof is missing 28 0xf0
# interpret_data: sof is missing 32 0x5f
# interpret_data: sof is missing 36 0xff
# interpret_data: sof is missing 40 0xa4
# interpret_data: sof is missing 44 0x5f
# interpret_data: sof is missing 48 0xb5
# interpret_data: sof is missing 52 0xe4
# interpret_data: sof is missing 56 0x17
# interpret_data: sof is missing 60 0xa4
# interpret_data: sof is missing 64 0xa1
# interpret_data: sof is missing 68 0xb5
# interpret_data: sof is missing 72 0x17
# interpret_data: sof is missing 76 0xea
# interpret_data: sof is missing 80 0x17
# interpret_data: sof is missing 84 0xb5
# interpret_data: sof is missing 88 0x3b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x95
# interpret_data: sof is missing 4 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0xa
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 12 0x8f
# interpret_data: sof is missing 16 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x3f
# interpret_data: sof is missing 0 0xe4
# interpret_data: sof is missing 4 0x81
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: sof is missing 4 0xff
# interpret_data: sof is missing 8 0x3f
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xb5
# interpret_data: sof is missing 20 0x90
# interpret_data: sof is missing 0 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0x3d
# interpret_data: sof is missing 8 0x90
# interpret_data: sof is missing 12 0xb5
# interpret_data: sof is missing 16 0x0
# interpret_data: sof is missing 20 0x90
# interpret_data: sof is missing 24 0x5d
# interpret_data: sof is missing 28 0xf0
# interpret_data: sof is missing 32 0x90
# interpret_data: sof is missing 36 0xb0
# interpret_data: sof is missing 40 0x3f
# interpret_data: sof is missing 44 0x90
# interpret_data: sof is missing 48 0xb5
# interpret_data: sof is missing 52 0xff
# interpret_data: sof is missing 56 0xa1
# interpret_data: sof is missing 60 0x5d
# interpret_data: sof is missing 64 0xb5
# interpret_data: sof is missing 68 0x8f
# interpret_data: sof is missing 72 0x0
# interpret_data: sof is missing 76 0x3d
# interpret_data: sof is missing 80 0x8f
# interpret_data: sof is missing 84 0xe4
# interpret_data: sof is missing 88 0xb0
# interpret_data: sof is missing 92 0x8f
# interpret_data: sof is missing 96 0x4a
# interpret_data: sof is missing 100 0x5d
# interpret_data: sof is missing 104 0x37
# interpret_data: sof is missing 108 0x4a
# interpret_data: sof is missing 112 0xa1
# interpret_data: sof is missing 116 0x37
# interpret_data: sof is missing 120 0xf5
# interpret_data: sof is missing 124 0x8f
# interpret_data: sof is missing 128 0x95
# interpret_data: sof is missing 132 0xb5
# interpret_data: sof is missing 136 0xb5
# interpret_data: sof is missing 140 0x8f
# interpret_data: sof is missing 144 0x57
# interpret_data: sof is missing 148 0xf7
# interpret_data: sof is missing 152 0x8f
# interpret_data: sof is missing 156 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x3f
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 12 0x20
# interpret_data: sof is missing 16 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x21
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x24
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0xea
# interpret_data: sof is missing 8 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x90
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x21
# interpret_data: sof is missing 8 0xe4
# 2026-07-10 09:55:14,639 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x84
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: sof is missing 4 0xbb
# interpret_data: sof is missing 8 0xb0
# interpret_data: sof is missing 0 0xef
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: sof is missing 4 0xea
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x9b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x2f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x35
# interpret_data: sof is missing 8 0x37
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0x2a
# interpret_data: sof is missing 8 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0xea
# interpret_data: sof is missing 8 0x5f
# interpret_data: sof is missing 12 0x37
# interpret_data: sof is missing 16 0xff
# interpret_data: sof is missing 20 0x30
# interpret_data: sof is missing 24 0x3d
# interpret_data: sof is missing 28 0xfd
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: sof is missing 4 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb0
# interpret_data: sof is missing 4 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x95
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x30
# interpret_data: sof is missing 4 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0x0
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 12 0x5f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: sof is missing 4 0xff
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 12 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5a
# interpret_data: sof is missing 4 0x5d
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 12 0x5f
# interpret_data: sof is missing 16 0x3f
# interpret_data: sof is missing 20 0x8f
# interpret_data: sof is missing 24 0x21
# interpret_data: sof is missing 28 0xe0
# interpret_data: sof is missing 32 0x8f
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0x9b
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0xb5
# interpret_data: sof is missing 8 0x8f
# interpret_data: sof is missing 12 0x30
# interpret_data: sof is missing 16 0x1d
# interpret_data: sof is missing 20 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0xea
# interpret_data: sof is missing 8 0x57
# interpret_data: sof is missing 12 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf7
# interpret_data: sof is missing 4 0x9b
# interpret_data: incomplete data
# 2026-07-10 09:55:15,173 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x35
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x95
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0x24
# interpret_data: sof is missing 12 0x5f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xef
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0xe1
# interpret_data: sof is missing 8 0x3b
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0x24
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0x9b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xef
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 12 0xaf
# interpret_data: sof is missing 16 0x2a
# interpret_data: sof is missing 20 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x3b
# interpret_data: sof is missing 8 0x21
# interpret_data: sof is missing 12 0x81
# interpret_data: sof is missing 16 0x1d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1f
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0x57
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xf7
# interpret_data: sof is missing 20 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xff
# interpret_data: sof is missing 4 0x8f
# interpret_data: sof is missing 8 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x3b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xf7
# interpret_data: sof is missing 8 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1d
# interpret_data: sof is missing 4 0x3d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x21
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x90
# interpret_data: sof is missing 4 0xef
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0xf0
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xf5
# interpret_data: sof is missing 8 0xf5
# interpret_data: sof is missing 12 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0xaf
# interpret_data: sof is missing 8 0xaf
# interpret_data: sof is missing 12 0x84
# interpret_data: sof is missing 16 0x24
# interpret_data: sof is missing 20 0xaf
# interpret_data: sof is missing 24 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe4
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0x81
# interpret_data: sof is missing 12 0xe0
# interpret_data: sof is missing 16 0x17
# interpret_data: sof is missing 20 0x81
# interpret_data: sof is missing 24 0x3b
# interpret_data: sof is missing 28 0xa1
# interpret_data: sof is missing 32 0x81
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: incomplete data
# 2026-07-10 09:55:15,693 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0x95
# interpret_data: sof is missing 12 0x1d
# interpret_data: sof is missing 16 0x0
# interpret_data: sof is missing 20 0x95
# interpret_data: sof is missing 24 0x4a
# interpret_data: sof is missing 28 0x8f
# interpret_data: sof is missing 32 0x95
# interpret_data: sof is missing 36 0x4a
# interpret_data: sof is missing 40 0xe4
# interpret_data: sof is missing 44 0x35
# interpret_data: sof is missing 48 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa4
# interpret_data: sof is missing 4 0xe1
# interpret_data: sof is missing 8 0x35
# interpret_data: sof is missing 0 0xa
# interpret_data: sof is missing 4 0xf7
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x90
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfd
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0xaf
# interpret_data: sof is missing 12 0x35
# interpret_data: sof is missing 16 0xb5
# interpret_data: sof is missing 20 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0x4a
# interpret_data: sof is missing 8 0xb5
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xa1
# interpret_data: sof is missing 20 0x35
# interpret_data: sof is missing 24 0xaf
# interpret_data: sof is missing 28 0x1d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa
# interpret_data: sof is missing 4 0xaf
# interpret_data: sof is missing 8 0xfb
# interpret_data: sof is missing 12 0x1d
# interpret_data: sof is missing 16 0x30
# interpret_data: sof is missing 20 0xfb
# interpret_data: sof is missing 24 0xb5
# interpret_data: sof is missing 28 0x2f
# interpret_data: sof is missing 32 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5a
# interpret_data: sof is missing 4 0x2a
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 12 0x95
# interpret_data: sof is missing 16 0x8f
# interpret_data: sof is missing 20 0xf5
# interpret_data: sof is missing 24 0x81
# interpret_data: sof is missing 28 0x20
# interpret_data: sof is missing 32 0xf5
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x95
# interpret_data: sof is missing 8 0xf5
# interpret_data: sof is missing 12 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0x35
# interpret_data: sof is missing 8 0xb5
# interpret_data: sof is missing 12 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0xfd
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0x1d
# interpret_data: sof is missing 8 0x81
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0x81
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x95
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0xfd
# interpret_data: sof is missing 12 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1d
# interpret_data: sof is missing 4 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: sof is missing 4 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0xea
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0xfd
# interpret_data: sof is missing 8 0x2a
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x9b
# interpret_data: sof is missing 8 0x37
# interpret_data: sof is missing 12 0x30
# interpret_data: sof is missing 16 0x24
# interpret_data: sof is missing 20 0x37
# interpret_data: sof is missing 24 0x5f
# interpret_data: sof is missing 28 0xaf
# interpret_data: sof is missing 32 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0x37
# interpret_data: sof is missing 12 0xaf
# interpret_data: sof is missing 16 0xb0
# interpret_data: sof is missing 20 0x37
# interpret_data: sof is missing 24 0x21
# interpret_data: sof is missing 28 0xaf
# interpret_data: sof is missing 32 0x37
# interpret_data: sof is missing 36 0x40
# interpret_data: sof is missing 40 0x30
# interpret_data: sof is missing 44 0xea
# interpret_data: sof is missing 48 0xe1
# interpret_data: sof is missing 52 0x3b
# interpret_data: sof is missing 56 0xea
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf7
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe0
# interpret_data: incomplete data
# 2026-07-10 09:55:16,259 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: sof is missing 4 0x95
# interpret_data: sof is missing 8 0xff
# interpret_data: sof is missing 12 0xa5
# interpret_data: sof is missing 16 0x8f
# interpret_data: sof is missing 20 0xff
# interpret_data: sof is missing 24 0x40
# interpret_data: sof is missing 28 0xb5
# interpret_data: sof is missing 32 0xe4
# interpret_data: sof is missing 36 0xb5
# interpret_data: sof is missing 40 0xb0
# interpret_data: sof is missing 44 0xa4
# interpret_data: sof is missing 48 0x20
# interpret_data: sof is missing 52 0xe4
# interpret_data: sof is missing 56 0xaf
# interpret_data: sof is missing 60 0x4a
# interpret_data: sof is missing 64 0x95
# interpret_data: sof is missing 68 0xaf
# interpret_data: sof is missing 72 0xb5
# interpret_data: sof is missing 76 0xf0
# interpret_data: sof is missing 80 0xaf
# interpret_data: sof is missing 84 0xf7
# interpret_data: sof is missing 88 0x84
# interpret_data: sof is missing 92 0x10
# interpret_data: sof is missing 0 0x1d
# interpret_data: sof is missing 4 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x10
# interpret_data: sof is missing 12 0xfb
# interpret_data: sof is missing 16 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: sof is missing 4 0x9b
# interpret_data: sof is missing 8 0x10
# interpret_data: sof is missing 0 0xe0
# interpret_data: sof is missing 4 0x3f
# interpret_data: sof is missing 8 0x10
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xbb
# interpret_data: sof is missing 4 0xe0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0x95
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0xe1
# interpret_data: sof is missing 8 0x95
# interpret_data: sof is missing 12 0x17
# interpret_data: sof is missing 16 0xe4
# interpret_data: sof is missing 20 0x17
# interpret_data: sof is missing 24 0xf0
# interpret_data: sof is missing 28 0x57
# interpret_data: sof is missing 32 0x17
# interpret_data: sof is missing 36 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xb5
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 12 0x17
# interpret_data: sof is missing 16 0xa1
# interpret_data: sof is missing 20 0xfd
# interpret_data: sof is missing 24 0x57
# interpret_data: sof is missing 28 0xfb
# interpret_data: sof is missing 32 0xfd
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0x5d
# interpret_data: sof is missing 8 0xfd
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xe4
# interpret_data: sof is missing 20 0xff
# interpret_data: sof is missing 24 0xb0
# interpret_data: sof is missing 28 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: sof is missing 4 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: sof is missing 4 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0xff
# interpret_data: sof is missing 12 0xb5
# interpret_data: sof is missing 16 0x2a
# interpret_data: sof is missing 20 0x5f
# interpret_data: sof is missing 24 0x17
# interpret_data: sof is missing 28 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0x35
# interpret_data: sof is missing 8 0x5f
# interpret_data: sof is missing 12 0x5f
# interpret_data: sof is missing 16 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x5f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0x84
# interpret_data: sof is missing 0 0xe1
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x84
# interpret_data: sof is missing 12 0x57
# interpret_data: sof is missing 16 0xfd
# interpret_data: sof is missing 20 0x95
# interpret_data: sof is missing 24 0xa1
# interpret_data: sof is missing 28 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0xe1
# interpret_data: sof is missing 8 0x3f
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xf7
# interpret_data: sof is missing 20 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: sof is missing 4 0xaf
# interpret_data: sof is missing 8 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0x84
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 0 0xe4
# interpret_data: sof is missing 4 0xe4
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0xff
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 0 0x2f
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x2a
# interpret_data: sof is missing 12 0x81
# interpret_data: sof is missing 16 0x8f
# interpret_data: sof is missing 20 0x2a
# interpret_data: sof is missing 24 0xa
# interpret_data: sof is missing 28 0x3b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0xfd
# interpret_data: sof is missing 8 0x2a
# interpret_data: sof is missing 12 0x3d
# interpret_data: sof is missing 16 0x0
# interpret_data: sof is missing 20 0x4a
# interpret_data: sof is missing 24 0xb0
# interpret_data: sof is missing 28 0xaf
# interpret_data: sof is missing 32 0xa1
# interpret_data: sof is missing 36 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3d
# interpret_data: sof is missing 4 0x30
# interpret_data: sof is missing 8 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x0
# interpret_data: sof is missing 8 0xa1
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0xe1
# interpret_data: sof is missing 20 0xb5
# interpret_data: sof is missing 24 0x40
# interpret_data: sof is missing 28 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: sof is missing 4 0x2a
# interpret_data: sof is missing 8 0xb5
# interpret_data: sof is missing 12 0x46
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0xb5
# interpret_data: sof is missing 12 0xaf
# interpret_data: sof is missing 16 0x2a
# interpret_data: sof is missing 20 0xb5
# interpret_data: incomplete data
# 2026-07-10 09:55:16,797 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0xe1
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 12 0x17
# interpret_data: sof is missing 16 0x2a
# interpret_data: sof is missing 20 0xa1
# interpret_data: sof is missing 24 0x4a
# interpret_data: sof is missing 28 0x81
# interpret_data: sof is missing 32 0x24
# interpret_data: sof is missing 36 0xa1
# interpret_data: sof is missing 40 0xb0
# interpret_data: sof is missing 44 0xe4
# interpret_data: sof is missing 48 0x5f
# interpret_data: sof is missing 52 0x21
# interpret_data: sof is missing 56 0xf5
# interpret_data: sof is missing 60 0x8f
# interpret_data: sof is missing 64 0x5d
# interpret_data: sof is missing 68 0x90
# interpret_data: sof is missing 72 0xaf
# interpret_data: sof is missing 76 0x5f
# interpret_data: sof is missing 80 0xfb
# interpret_data: sof is missing 84 0xbb
# interpret_data: sof is missing 88 0xe4
# interpret_data: sof is missing 92 0xb0
# interpret_data: sof is missing 96 0xaf
# interpret_data: sof is missing 100 0x17
# interpret_data: sof is missing 104 0x3f
# interpret_data: sof is missing 108 0xa1
# interpret_data: sof is missing 112 0x95
# interpret_data: sof is missing 116 0x3f
# interpret_data: sof is missing 120 0xb0
# interpret_data: sof is missing 124 0x37
# interpret_data: sof is missing 128 0xfb
# interpret_data: sof is missing 132 0x3f
# interpret_data: sof is missing 136 0xea
# interpret_data: sof is missing 140 0xfb
# interpret_data: sof is missing 144 0xff
# interpret_data: sof is missing 148 0x0
# interpret_data: sof is missing 152 0xfb
# interpret_data: sof is missing 156 0x40
# interpret_data: sof is missing 160 0x57
# interpret_data: sof is missing 164 0xfb
# interpret_data: sof is missing 168 0xf7
# interpret_data: sof is missing 172 0xb5
# interpret_data: sof is missing 176 0x35
# interpret_data: sof is missing 180 0x4a
# interpret_data: sof is missing 184 0x0
# interpret_data: sof is missing 188 0x30
# interpret_data: sof is missing 192 0xe4
# interpret_data: sof is missing 196 0xb5
# interpret_data: sof is missing 200 0xa4
# interpret_data: sof is missing 204 0x4a
# interpret_data: sof is missing 208 0x5d
# interpret_data: sof is missing 212 0xe4
# interpret_data: sof is missing 216 0xa1
# interpret_data: sof is missing 220 0xf7
# interpret_data: sof is missing 224 0xe4
# interpret_data: sof is missing 228 0x0
# interpret_data: sof is missing 232 0x37
# interpret_data: sof is missing 236 0xe4
# interpret_data: sof is missing 240 0x4a
# interpret_data: sof is missing 244 0xff
# interpret_data: sof is missing 248 0x5f
# interpret_data: sof is missing 252 0x95
# interpret_data: sof is missing 256 0xaf
# interpret_data: sof is missing 260 0x5f
# interpret_data: sof is missing 264 0xa1
# interpret_data: sof is missing 268 0x35
# interpret_data: sof is missing 272 0xa1
# interpret_data: sof is missing 276 0xb5
# interpret_data: sof is missing 280 0xea
# interpret_data: sof is missing 284 0xa1
# interpret_data: sof is missing 288 0x2a
# interpret_data: sof is missing 292 0xe4
# interpret_data: sof is missing 296 0xa1
# interpret_data: sof is missing 300 0xb5
# interpret_data: sof is missing 304 0xfd
# interpret_data: sof is missing 308 0x37
# interpret_data: sof is missing 312 0xb5
# interpret_data: sof is missing 316 0xea
# interpret_data: sof is missing 320 0x5f
# interpret_data: sof is missing 324 0x37
# interpret_data: sof is missing 328 0x20
# interpret_data: sof is missing 332 0x5f
# interpret_data: sof is missing 336 0x4a
# interpret_data: sof is missing 340 0x95
# interpret_data: sof is missing 344 0x5f
# interpret_data: sof is missing 348 0x30
# interpret_data: sof is missing 352 0xf7
# interpret_data: sof is missing 356 0x5f
# interpret_data: sof is missing 360 0x24
# interpret_data: sof is missing 364 0x37
# interpret_data: sof is missing 368 0xf0
# interpret_data: sof is missing 372 0x37
# interpret_data: sof is missing 376 0xe1
# interpret_data: sof is missing 380 0xf0
# interpret_data: sof is missing 384 0xf0
# interpret_data: sof is missing 388 0xe4
# interpret_data: sof is missing 392 0xf0
# interpret_data: sof is missing 396 0xa1
# interpret_data: sof is missing 400 0x17
# interpret_data: sof is missing 404 0xf0
# interpret_data: sof is missing 408 0x4a
# interpret_data: sof is missing 412 0xa
# interpret_data: sof is missing 416 0xf0
# interpret_data: sof is missing 420 0xf0
# interpret_data: sof is missing 424 0xff
# interpret_data: sof is missing 428 0xf0
# interpret_data: sof is missing 432 0xe4
# interpret_data: sof is missing 436 0x9b
# interpret_data: sof is missing 440 0xaf
# interpret_data: sof is missing 444 0x17
# interpret_data: sof is missing 448 0xb5
# interpret_data: sof is missing 452 0xe4
# interpret_data: sof is missing 456 0xbb
# interpret_data: sof is missing 460 0xea
# interpret_data: sof is missing 464 0x8f
# interpret_data: sof is missing 468 0xb5
# interpret_data: sof is missing 472 0x1d
# interpret_data: sof is missing 476 0x95
# interpret_data: sof is missing 480 0x0
# interpret_data: sof is missing 484 0xfb
# interpret_data: sof is missing 488 0x95
# interpret_data: sof is missing 492 0xb5
# interpret_data: sof is missing 496 0xe4
# interpret_data: sof is missing 500 0xa
# interpret_data: sof is missing 504 0xb5
# interpret_data: sof is missing 508 0xe1
# interpret_data: sof is missing 512 0xa
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x8f
# interpret_data: sof is missing 8 0x84
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0x30
# interpret_data: sof is missing 20 0xb5
# interpret_data: sof is missing 24 0x5d
# interpret_data: sof is missing 28 0xf7
# interpret_data: sof is missing 32 0xb5
# interpret_data: sof is missing 36 0x4a
# interpret_data: sof is missing 40 0xb5
# interpret_data: sof is missing 44 0xb0
# interpret_data: sof is missing 48 0xff
# interpret_data: sof is missing 52 0xea
# interpret_data: sof is missing 56 0x5f
# interpret_data: sof is missing 60 0xa
# interpret_data: sof is missing 64 0x3b
# interpret_data: sof is missing 68 0x5f
# interpret_data: sof is missing 72 0x5f
# interpret_data: sof is missing 76 0x24
# interpret_data: sof is missing 80 0x5f
# interpret_data: sof is missing 84 0xa1
# interpret_data: sof is missing 88 0xe4
# interpret_data: sof is missing 92 0xff
# interpret_data: sof is missing 96 0x17
# interpret_data: sof is missing 100 0xea
# interpret_data: sof is missing 104 0x5f
# interpret_data: sof is missing 108 0xaf
# interpret_data: sof is missing 112 0x35
# interpret_data: sof is missing 116 0x5f
# interpret_data: sof is missing 120 0xa1
# interpret_data: sof is missing 124 0xa1
# interpret_data: sof is missing 128 0x5f
# interpret_data: sof is missing 132 0x4a
# interpret_data: sof is missing 136 0x8f
# interpret_data: sof is missing 140 0x5f
# interpret_data: sof is missing 144 0x5d
# interpret_data: sof is missing 148 0x30
# interpret_data: sof is missing 152 0x5f
# interpret_data: sof is missing 156 0xa1
# interpret_data: sof is missing 160 0x20
# interpret_data: sof is missing 164 0x17
# interpret_data: sof is missing 168 0x30
# interpret_data: sof is missing 172 0x84
# interpret_data: sof is missing 176 0x17
# interpret_data: sof is missing 180 0x4a
# interpret_data: sof is missing 184 0xef
# interpret_data: sof is missing 188 0x17
# interpret_data: sof is missing 192 0x24
# interpret_data: sof is missing 196 0xef
# interpret_data: sof is missing 200 0x17
# interpret_data: sof is missing 204 0x40
# interpret_data: sof is missing 208 0x17
# interpret_data: sof is missing 212 0xf7
# interpret_data: sof is missing 216 0x1d
# interpret_data: sof is missing 220 0x5d
# interpret_data: sof is missing 224 0xf7
# interpret_data: sof is missing 228 0x17
# interpret_data: sof is missing 232 0x9b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0x30
# interpret_data: sof is missing 8 0x35
# interpret_data: sof is missing 12 0xef
# interpret_data: sof is missing 16 0xf7
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x35
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3d
# interpret_data: sof is missing 4 0xea
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x30
# interpret_data: sof is missing 12 0x17
# interpret_data: sof is missing 16 0xea
# interpret_data: sof is missing 20 0xea
# interpret_data: sof is missing 0 0x35
# interpret_data: sof is missing 4 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0x8f
# interpret_data: sof is missing 8 0xea
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0x95
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0xea
# interpret_data: sof is missing 12 0x37
# interpret_data: sof is missing 16 0xb0
# interpret_data: sof is missing 20 0xea
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3b
# interpret_data: sof is missing 4 0xe4
# interpret_data: sof is missing 8 0x37
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xb5
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x1f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5f
# interpret_data: sof is missing 4 0x5f
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 0 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x30
# interpret_data: sof is missing 8 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3b
# interpret_data: sof is missing 4 0x0
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0xaf
# interpret_data: sof is missing 8 0xe4
# interpret_data: sof is missing 12 0x4a
# interpret_data: sof is missing 16 0x1d
# interpret_data: sof is missing 20 0xe4
# interpret_data: sof is missing 24 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0xea
# interpret_data: incomplete data
# 2026-07-10 09:55:17,329 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: sof is missing 4 0x20
# interpret_data: sof is missing 8 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x3b
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0xe4
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: sof is missing 4 0x8f
# interpret_data: sof is missing 8 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x8f
# interpret_data: sof is missing 4 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: incomplete data
# 2026-07-10 09:55:17,857 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x30
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: sof is missing 4 0x24
# interpret_data: sof is missing 8 0xbb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x8f
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: sof is missing 4 0x37
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xff
# interpret_data: sof is missing 4 0x1d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: sof is missing 4 0xe1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: sof is missing 4 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x21
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xff
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: sof is missing 4 0x81
# interpret_data: sof is missing 8 0x3d
# interpret_data: sof is missing 0 0x57
# interpret_data: sof is missing 4 0xf0
# interpret_data: sof is missing 8 0x3d
# interpret_data: sof is missing 12 0x2a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x5d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x17
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb0
# interpret_data: sof is missing 4 0x0
# interpret_data: sof is missing 8 0x20
# interpret_data: incomplete data
# 2026-07-10 09:55:18,390 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x5d
# interpret_data: sof is missing 4 0x17
# interpret_data: sof is missing 8 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xfb
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x4a
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x37
# interpret_data: sof is missing 4 0x2a
# interpret_data: sof is missing 8 0x95
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: sof is missing 4 0x5d
# interpret_data: sof is missing 8 0x95
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xa1
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: sof is missing 4 0x37
# interpret_data: sof is missing 8 0x95
# interpret_data: sof is missing 12 0x95
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x24
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x30
# interpret_data: sof is missing 4 0xf0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x35
# interpret_data: incomplete data
# 2026-07-10 09:55:18,921 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x81
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x20
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x21
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x24
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x9b
# interpret_data: sof is missing 8 0x17
# interpret_data: sof is missing 0 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x57
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: sof is missing 4 0x3d
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xaf
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: sof is missing 4 0x3d
# interpret_data: incomplete data
# 2026-07-10 09:55:19,468 [TJ-Monopix2 - W00R00] - WARNING Timeout while waiting for register response.
# interpret_data: sof is missing 0 0x17
# interpret_data: sof is missing 4 0x0
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xb5
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0x40
# interpret_data: incomplete data
# interpret_data: sof is missing 0 0xf0
# interpret_data: incomplete data
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 14
#      10 daq.reset_fifo()  # Clear FIFO before reading data
#      11 raw_data = daq["FIFO"].get_data()  # Get FIFO contents
#      12 hit_data, reg_data = chip.interpret_data(raw_data)  # Interpret data
#      13
# ---> 14 print(chip.registers["ITHR"].read())  # Read registers using register object
#      15 print(chip._get_register_value(151))  # Read registers (almost) directly
#
# File ~/git/tj-monopix2-daq/tjmonopix2/system/tjmonopix2.py:172, in Register.read(self)
#     171 def read(self):
# --> 172     val = self.chip._get_register_value(self['address'])
#     173     bit_mask = eval('0b' + '1' * self['size']) << self['offset']
#     174     val = (val & bit_mask) >> self['offset']
#
# File ~/git/tj-monopix2-daq/tjmonopix2/system/tjmonopix2.py:1054, in TJMonoPix2._get_register_value(self, address, timeout, tries)
#    1052         self.log.warning('Timeout while waiting for register response.')
#    1053 else:
# -> 1054     raise RuntimeError('Timeout while waiting for register response.')
#
# RuntimeError: Timeout while waiting for register response.

# %%
# Closing
daq.close()
